# %% [markdown]
# <html> <h1 style="font-style:bold; color:blue;"> Machine Learning in Finance </h1> </html>

# %% [markdown]
# <html> <h1 style="font-style:italic; color:blue;"> Week-7 </h1> </html>

# %% [markdown]
# ## LSTM (Long Short-Term Memory)
#
# ## GOLD-2022 dataset
#
# ### Predictions of The Highest & Lowest prices DURING five(5) following minutes
# - Early-Stopping
# - Loss function: MSE
#
# ### length of analysed history (sliding window)- 50 minutes ago
#
# #### dataset for training: 30.000 rows (minutes) ~ 1 month
# #### train / test = 90 /10

# %% [markdown]
# ___________________________![image.png](attachment:a5936ca3-0185-4703-98ee-66f8d6404486.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import*
import seaborn as sns

# %%
# !which python
# Out:
# 'which' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# _____________________![image.png](attachment:32a2c2ad-40e3-41b4-843b-19fa5bc69678.png)

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\srava\anaconda3\python.exe

# %%
import sys
# !{sys.executable} -m pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\srava\anaconda3\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\srava\anaconda3\lib\site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\srava\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\srava\anaconda3\lib\site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\srava\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\srava\anaconda3\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\srava\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.76.0-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Downloading keras-3.12.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\srava\anaconda3\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\srava\anaconda3\lib\site-packages (from tensorflow) (3.12.1)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.3-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\srava\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\srava\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\srava\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\srava\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\srava\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8)
# Requirement already satisfied: pillow in c:\users\srava\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.1.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\srava\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\srava\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\srava\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Collecting namex (from keras>=3.10.0->tensorflow)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Downloading optree-0.17.0-cp313-cp313-win_amd64.whl.metadata (34 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\srava\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\srava\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\srava\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\srava\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.0)
# Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl (332.0 MB)
#    ---------------------------------------- 0.0/332.0 MB ? eta -:--:--
#    ---------------------------------------- 2.6/332.0 MB 14.0 MB/s eta 0:00:24
#     --------------------------------------- 5.5/332.0 MB 13.9 MB/s eta 0:00:24
#    - -------------------------------------- 8.4/332.0 MB 13.9 MB/s eta 0:00:24
#    - -------------------------------------- 11.3/332.0 MB 13.9 MB/s eta 0:00:24
#    - -------------------------------------- 14.2/332.0 MB 13.8 MB/s eta 0:00:23
#    -- ------------------------------------- 16.8/332.0 MB 13.8 MB/s eta 0:00:23
#    -- ------------------------------------- 19.7/332.0 MB 13.8 MB/s eta 0:00:23
#    -- ------------------------------------- 22.5/332.0 MB 13.8 MB/s eta 0:00:23
#    --- ------------------------------------ 25.4/332.0 MB 13.8 MB/s eta 0:00:23
#    --- ------------------------------------ 28.0/332.0 MB 13.8 MB/s eta 0:00:23
#    --- ------------------------------------ 31.2/332.0 MB 13.8 MB/s eta 0:00:22
#    ---- ----------------------------------- 34.1/332.0 MB 13.8 MB/s eta 0:00:22
#    ---- ----------------------------------- 36.7/332.0 MB 13.8 MB/s eta 0:00:22
#    ---- ----------------------------------- 39.6/332.0 MB 13.8 MB/s eta 0:00:22
#    ----- ---------------------------------- 42.5/332.0 MB 13.8 MB/s eta 0:00:21
#    ----- ----------------------------------
MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 11.8 MB/s  0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading keras-3.12.0-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 11.4 MB/s  0:00:00
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    --- ------------------------------------ 2.6/26.4 MB 14.5 MB/s eta 0:00:02
#    -------- ------------------------------- 5.5/26.4 MB 14.1 MB/s eta 0:00:02
#    ------------ --------------------------- 8.4/26.4 MB 14.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 11.3/26.4 MB 13.9 MB/s eta 0:00:02
#    --------------------- ------------------ 14.2/26.4 MB 13.9 MB/s eta 0:00:01
#    ------------------------- -------------- 17.0/26.4 MB 13.9 MB/s eta 0:00:01
#    ------------------------------ --------- 19.9/26.4 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 22.8/26.4 MB 13.9 MB/s eta 0:00:01
#    -------------------------------------- - 25.4/26.4 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 13.1 MB/s  0:00:02
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.17.0-cp313-cp313-win_amd64.whl (316 kB)
# Installing collected packages: namex, libclang, flatbuffers, termcolor, tensorboard-data-server, optree, opt_einsum, ml_dtypes, grpcio, google_pasta, gast, astunparse, absl-py, tensorboard, keras, tensorflow
#
#    -- -------------------------------------  1/16 [libclang]
#    -- -------------------------------------  1/16 [libclang]
#    -- -------------------------------------  1/16 [libclang]
#    -- -------------------------------------  1/16 [libclang]
#    -- -------------------------------------  1/16 [libclang]
#    -- -------------------------------------  1/16 [libclang]
#    ----- ----------------------------------  2/16 [flatbuffers]
#    ------------ ---------------------------  5/16 [optree]
#    --------------- ------------------------  6/16 [opt_einsum]
#    --------------- ------------------------  6/16 [opt_einsum]
#    --------------- ------------------------  6/16 [opt_einsum]
#    -------------------- -------------------  8/16 [grpcio]
#    -------------------- -------------------  8/16 [grpcio]
#    -------------------- -------------------  8/16 [grpcio]
#    -------------------- -------------------  8/16 [grpcio]
#    -------------------- -------------------  8/16 [grpcio]
#    ---------------------- -----------------  9/16 [google_pasta]
#    ---------------------- -----------------  9/16 [google_pasta]
#    ------------------------- -------------- 10/16 [gast]
#    ------------------------------ --------- 12/16 [absl-py]
#    ------------------------------ --------- 12/16 [absl-py]
#    ------------------------------ --------- 12/16 [absl-py]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    -------------------------------- ------- 13/16 [tensorboard]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ----------------------------------- ---- 14/16 [keras]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ------------------------------------- -- 15/16 [tensorflow]
#    ---------------------------------------- 16/16 [tensorflow]
#
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 flatbuffers-25.9.23 gast-0.6.0 google_pasta-0.2.0 grpcio-1.76.0 keras-3.12.0 libclang-18.1.1 ml_dtypes-0.5.3 namex-0.1.0 opt_einsum-3.4.0 optree-0.17.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.2.0

# %% [markdown]
# __________________![image.png](attachment:35d39cff-5be9-4339-8a7b-93d059e86283.png)

# %%
import tensorflow as tf
from tensorflow import keras

# %% [raw]
# print(tf.__version__)

# %% [markdown]
# _____________________![image.png](attachment:1565fe56-e25f-426a-b31d-492e53260440.png)

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ___________________![image.png](attachment:b64170db-97a0-4e8d-9b75-c05033a49f46.png)

# %%
np.random.seed(19)

# %% [markdown]
# <html> <h2 style=" color:blue;"> Data </h2> </html>

# %%
# We use a slightly different normalisation principle for prices.
# We use the same principle as in the practical session in Week-6 for Volumes and Deltas.

# We use another principlefor prices:
# For normalisation, it is not necessary for the normalised columns' values to be in the range between [0,1].
# What is more important is that all the values in these columns are approximately the same order of magnitude, 
# i.e. do not differ by hundreds or more times.
# Therefore we can simply divide the gold prices by 1000

# %% [markdown]
# _____________________________![image.png](attachment:e1d0b29b-673f-4a1a-9cfc-af75e18f3797.png)

# %%
data = pd.read_csv('GOLD_2022_normalised_NEW-1000.csv', low_memory=False, sep=',')
data.head()
# Out:
#    Open_Bid  High_Bid   Low_Bid  Close_Bid  Volume_Bid  Open_Ask  High_Ask  \
# 0  1.828604  1.829628  1.828544   1.829504    0.009718  1.829656  1.830936
# 1  1.829504  1.830104  1.829398   1.830004    0.007151  1.829936  1.830676
# 2  1.830098  1.830604  1.829998   1.830534    0.011126  1.830612  1.831226
# 3  1.830534  1.830704  1.830504   1.830674    0.001991  1.831156  1.831306
# 4  1.830674  1.830674  1.830448   1.830508    0.006660  1.831026  1.831181
#
#     Low_Ask  Close_Ask  Volume_Ask  Volume_Delta  Volume_Delta_abs  \
# 0  1.829386   1.830196    0.009050      0.629054          0.000709
# 1  1.829916   1.830632    0.009946      0.631369          0.002969
# 2  1.830516   1.831146    0.016555      0.633130          0.005766
# 3  1.831046   1.831046    0.006808      0.632720          0.005116
# 4  1.830886   1.831086    0.010739      0.632227          0.004332
#
#    Open_Delta  High_Delta  Low_Delta  Close_Delta  New_day  New_week  \
# 0    0.751830    0.691381   0.801417     0.836836        1         1
# 1    0.898229    0.865171   0.877922     0.851948        0         0
# 2    0.878867    0.853365   0.877922     0.855726        0         0
# 3    0.853365    0.858087   0.872255     0.912397        0         0
# 4    0.917119    0.880520   0.896812     0.863754        0         0
#
#    Y_High_Bid  Y_Low_Ask
# 0    1.829628   1.829386
# 1    1.830104   1.829916
# 2    1.830604   1.830516
# 3    1.830704   1.831046
# 4    1.830674   1.830886

# %%
# Out:
#    Open_Bid  High_Bid   Low_Bid  Close_Bid  Volume_Bid  Open_Ask
# 354689  1.825052  1.824752   1.824852    0.001409      0.629130
# 354690  1.824752  1.824552   1.824552    0.001165      0.628807
# 354691  1.824675  1.824252   1.824452    0.002884      0.629365
# 354692  1.824452  1.823852   1.823852    0.001494      0.627841
# 354693  1.824252  1.823852   1.824252    0.000892      0.625696
#
#         Volume_Delta_abs  Open_Delta  High_Delta  Low_Delta  Close_Delta  \
# 354689          0.000588    0.857615    0.834002   0.857615     0.857615
# 354690          0.001101    0.857615    0.857615   0.807792     0.857615
# 354691          0.000215    0.868713    0.862102   0.786541     0.857615
# 354692          0.002636    0.834002    0.834002   0.804486     0.804959
# 354693          0.006044    0.880520    0.813932   0.800472     0.813932
#
#         New_day  New_week  Y_High_Bid  Y_Low_Ask
# 354689        0         0    1.824348   1.824752
# 354690        0         0    1.824148   1.824552
# 354691        0         0    1.824090   1.824252
# 354692        0         0    1.823748   1.823852
# 354693        0         0    1.823463   1.823852

# %% [markdown]
# ___________________________![image.png](attachment:728091c5-6d2a-4256-83c6-b6ee7dd6f4e4.png)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354694 entries, 0 to 354693
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Open_Bid          354694 non-null  float64
#  1   High_Bid          354694 non-null  float64
#  2   Low_Bid           354694 non-null  float64
#  3   Close_Bid         354694 non-null  float64
#  4   Volume_Bid        354694 non-null  float64
#  5   Open_Ask          354694 non-null  float64
#  6   High_Ask          354694 non-null  float64
#  7   Low_Ask           354694 non-null  float64
#  8   Close_Ask         354694 non-null  float64
#  9   Volume_Ask        354694 non-null  float64
#  10  Volume_Delta      354694 non-null  float64
#  11  Volume_Delta_abs  354694 non-null  float64
#  12  Open_Delta        354694 non-null  float64
#  13  High_Delta        354694 non-null  float64
#  14  Low_Delta         354694 non-null  float64
#  15  Close_Delta       354694 non-null  float64
#  16  New_day           354694 non-null  int64
#  17  New_week          354694 non-null  int64
#  18  Y_High_Bid        354694 non-null  float64
#  19  Y_Low_Ask         354694 non-null  float64
# dtypes: float64(18), int64(2)
# memory usage: 54.1 MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354694 entries, 0 to 354693
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Open_Bid          354694 non-null  float64
#  1   High_Bid          354694 non-null  float64
#  2   Low_Bid           354694 non-null  float64
#  3   Close_Bid         354694 non-null  float64
#  4   Volume_Bid        354694 non-null  float64
#  5   Open_Ask          354694 non-null  float64
#  6   High_Ask          354694 non-null  float64
#  7   Low_Ask           354694 non-null  float64
#  8   Close_Ask         354694 non-null  float64
#  9   Volume_Ask        354694 non-null  float64
#  10  Volume_Delta      354694 non-null  float64
#  11  Volume_Delta_abs  354694 non-null  float64
#  12  Open_Delta        354694 non-null  float64
#  13  High_Delta        354694 non-null  float64
#  14  Low_Delta         354694 non-null  float64
#  15  Close_Delta       354694 non-null  float64
#  16  New_day           354694 non-null  int64
#  17  New_week          354694 non-null  int64
#  18  Y_High_Bid        354694 non-null  float64
#  19  Y_Low_Ask         354694 non-null  float64
# dtypes: float64(18), int64(2)
# memory usage: 54.1 MB

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cell.

# %%
# memory size reduction

columns_float =['Open_Bid', 'High_Bid', 'Low_Bid', 'Close_Bid', 'Volume_Bid', 
                'Open_Ask', 'High_Ask', 'Low_Ask', 'Close_Ask', 'Volume_Ask', 
                'Volume_Delta', 'Volume_Delta_abs', 
                'Open_Delta', 'High_Delta', 'Low_Delta', 'Close_Delta',
                'Y_High_Bid', 'Y_Low_Ask']

columns_integer =['New_day', 'New_week']

# %% [markdown]
# _____________________![image.png](attachment:99e84a83-a8b2-47fc-bd3f-bd28c73a7078.png)

# %%
for column in columns_float:
       data[column] = pd.to_numeric(data[column], downcast='float')
for column in columns_integer:
       data[column] = pd.to_numeric(data[column], downcast='integer')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354694 entries, 0 to 354693
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Open_Bid          354694 non-null  float32
#  1   High_Bid          354694 non-null  float32
#  2   Low_Bid           354694 non-null  float32
#  3   Close_Bid         354694 non-null  float32
#  4   Volume_Bid        354694 non-null  float32
#  5   Open_Ask          354694 non-null  float32
#  6   High_Ask          354694 non-null  float32
#  7   Low_Ask           354694 non-null  float32
#  8   Close_Ask         354694 non-null  float32
#  9   Volume_Ask        354694 non-null  float32
#  10  Volume_Delta      354694 non-null  float32
#  11  Volume_Delta_abs  354694 non-null  float32
#  12  Open_Delta        354694 non-null  float32
#  13  High_Delta        354694 non-null  float32
#  14  Low_Delta         354694 non-null  float32
#  15  Close_Delta       354694 non-null  float32
#  16  New_day           354694 non-null  int8
#  17  New_week          354694 non-null  int8
#  18  Y_High_Bid        354694 non-null  float32
#  19  Y_Low_Ask         354694 non-null  float32
# dtypes: float32(18), int8(2)
# memory usage: 25.0 MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354694 entries, 0 to 354693
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Open_Bid          354694 non-null  float32
#  1   High_Bid          354694 non-null  float32
#  2   Low_Bid           354694 non-null  float32
#  3   Close_Bid         354694 non-null  float32
#  4   Volume_Bid        354694 non-null  float32
#  5   Open_Ask          354694 non-null  float32
#  6   High_Ask          354694 non-null  float32
#  7   Low_Ask           354694 non-null  float32
#  8   Close_Ask         354694 non-null  float32
#  9   Volume_Ask        354694 non-null  float32
#  10  Volume_Delta      354694 non-null  float32
#  11  Volume_Delta_abs  354694 non-null  float32
#  12  Open_Delta        354694 non-null  float32
#  13  High_Delta        354694 non-null  float32
#  14  Low_Delta         354694 non-null  float32
#  15  Close_Delta       354694 non-null  float32
#  16  New_day           354694 non-null  int8
#  17  New_week          354694 non-null  int8
#  18  Y_High_Bid        354694 non-null  float32
#  19  Y_Low_Ask         354694 non-null  float32
# dtypes: float32(18), int8(2)
# memory usage: 25.0 MB

# %% [markdown]
# _____________________________![image.png](attachment:b4861676-3b86-4f05-8b1b-1fe0fb1192aa.png)

# %%
data.describe()
# Out:
#             Open_Bid       High_Bid        Low_Bid      Close_Bid  \
# count  354694.000000  354694.000000  354694.000000  354694.000000
# mean        1.801307       1.801587       1.801030       1.801308
# std         0.091688       0.091719       0.091654       0.091687
# min         1.614858       1.615848       1.614710       1.614858
# 25%         1.734037       1.734294       1.733790       1.734034
# 50%         1.804496       1.804728       1.804248       1.804492
# 75%         1.855088       1.855348       1.854847       1.855086
# max         2.069368       2.070358       2.066518       2.069358
#
#           Volume_Bid       Open_Ask       High_Ask        Low_Ask  \
# count  354694.000000  354694.000000  354694.000000  354694.000000
# mean        0.013636       1.801681       1.801959       1.801403
# 75%         1.855442       0.017790       0.630837          0.004939
# max         2.069802       0.579609       1.000000          1.000000
#
#           Open_Delta     High_Delta      Low_Delta   Close_Delta  \
# count  354694.000000  354694.000000  354694.000000  3.546940e+05
# mean        0.912002       0.912279       0.912270  9.119296e-01
# std         0.018467       0.017149       0.017005  1.719723e-02
# min         0.484534       0.285714       0.271547 -2.453763e-14
# 25%         0.902479       0.902479       0.902479  9.024794e-01
# 50%         0.913577       0.914286       0.914050  9.133412e-01
# 75%         0.923022       0.923022       0.923022  9.227863e-01
# max         0.999056       1.000000       0.999764  9.990555e-01
#
#              New_day       New_week     Y_High_Bid      Y_Low_Ask
# count  354694.000000  354694.000000  354694.000000  354694.000000
# mean        0.000727       0.000147       1.801587       1.801403
# std         0.026960       0.012107       0.091719       0.091655
# min         0.000000       0.000000       1.615848       1.615092
# 25%         0.000000       0.000000       1.734294       1.734153
# 50%         0.000000       0.000000       1.804728       1.804595
# 75%         0.000000       0.000000       1.855348       1.855202
# max         1.000000       1.000000       2.070358       2.067052

# %% [markdown]
# _____________________________![image.png](attachment:9a8db982-8fcb-426d-b321-dc15d076e361.png)

# %%
data.shape
# Out:
# (354694, 20)

# %%
# Out:
# (354694, 20)

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cell.

# %%
fig = plt.figure(figsize=(12, 5))
plt.rc('axes', titlesize= 30 ) 
sns.set_style('whitegrid')
sns.set_context(rc={'legend.fontsize': 20.0}) 

sns.displot( 
            data[['Open_Delta', 'Close_Delta']],
            height=8,
            aspect=1.7,
            kde=True,
            element="step",
            bins=100,
            alpha=0.03,          
                        
)

plt.title('Open_Delta & Close_Delta Price Distribution')
plt.xlabel('Price Delta', size= 20)
plt.ylabel('Numbers', size= 20)
plt.show()

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> Date Transformation </h3> </html>

# %%
# We will predict the Highest and Lowest prices DURING the next 5 minutes. 

# To do this in the data output (vector of answers), we shift prices sequentially to 5 minutes up, 
# and find max and min prices during these 5 minutes
# Then you need to delete the 5 last rows since there are no prices for the next 5 minutes. 
# Therefore, we will create an array of answers "data_ay" with the Highest and Lowest prices shifted sequentially to 5 rows up.

# %% [markdown]
# _________________________![image.png](attachment:e304ed0e-c9b9-4162-86a3-a6d8107cbc36.png)

# %%
n = data.shape[0]
n
# Out:
# 354694

# %%
# Out:
# 354694

# %% [markdown]
# _________________________![image.png](attachment:feab4059-209e-4467-9622-8e2eafdb304b.png)

# %%
p = data.shape[1]
p
# Out:
# 20

# %%
# Out:
# 20

# %% [markdown]
# __________________![image.png](attachment:6761bc27-2115-436c-b09f-07f73ed53e67.png)

# %%
data_ax = data.drop(['Y_High_Bid', 'Y_Low_Ask'], axis=1)

# %% [markdown]
# ________________![image.png](attachment:6e70d75b-dd41-4216-b55c-b9f5d3e0d0ee.png)

# %%
data_ax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354694 entries, 0 to 354693
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Open_Bid          354694 non-null  float32
#  1   High_Bid          354694 non-null  float32
#  2   Low_Bid           354694 non-null  float32
#  3   Close_Bid         354694 non-null  float32
#  4   Volume_Bid        354694 non-null  float32
#  5   Open_Ask          354694 non-null  float32
#  6   High_Ask          354694 non-null  float32
#  7   Low_Ask           354694 non-null  float32
#  8   Close_Ask         354694 non-null  float32
#  9   Volume_Ask        354694 non-null  float32
#  10  Volume_Delta      354694 non-null  float32
#  11  Volume_Delta_abs  354694 non-null  float32
#  12  Open_Delta        354694 non-null  float32
#  13  High_Delta        354694 non-null  float32
#  14  Low_Delta         354694 non-null  float32
#  15  Close_Delta       354694 non-null  float32
#  16  New_day           354694 non-null  int8
#  17  New_week          354694 non-null  int8
# dtypes: float32(16), int8(2)
# memory usage: 22.3 MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354694 entries, 0 to 354693
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Open_Bid          354694 non-null  float32
#  1   High_Bid          354694 non-null  float32
#  2   Low_Bid           354694 non-null  float32
#  3   Close_Bid         354694 non-null  float32
#  4   Volume_Bid        354694 non-null  float32
#  5   Open_Ask          354694 non-null  float32
#  6   High_Ask          354694 non-null  float32
#  7   Low_Ask           354694 non-null  float32
#  8   Close_Ask         354694 non-null  float32
#  9   Volume_Ask        354694 non-null  float32
#  10  Volume_Delta      354694 non-null  float32
#  11  Volume_Delta_abs  354694 non-null  float32
#  12  Open_Delta        354694 non-null  float32
#  13  High_Delta        354694 non-null  float32
#  14  Low_Delta         354694 non-null  float32
#  15  Close_Delta       354694 non-null  float32
#  16  New_day           354694 non-null  int8
#  17  New_week          354694 non-null  int8
# dtypes: float32(16), int8(2)
# memory usage: 22.3 MB

# %% [markdown]
# __________________________![image.png](attachment:f4e8e693-899b-4e74-bab9-8fd0ac8be78c.png)

# %%
data_ax.shape
# Out:
# (354694, 18)

# %%
# Out:
# (354694, 18)

# %% [markdown]
# __________________________![image.png](attachment:585dd4f1-9c19-4ebf-b27a-777e9e310457.png)

# %%
data_ay = data[['Y_High_Bid', 'Y_Low_Ask']]

# %% [markdown]
# ________________![image.png](attachment:71ad9fd4-6414-454b-9cb1-0e1fbb82c4c9.png)

# %%
data_ay.shape
# Out:
# (354694, 2)

# %%
# Out:
# (354694, 2)

# %% [markdown]
# ___________________![image.png](attachment:2a3e72cf-e549-416e-b1de-8de35e46841c.png)

# %%
data_ay.head(6)
# Out:
#    Y_High_Bid  Y_Low_Ask
# 0    1.829628   1.829386
# 1    1.830104   1.829916
# 2    1.830604   1.830516
# 3    1.830704   1.831046
# 4    1.830674   1.830886
# 5    1.830568   1.830046

# %%
# Out:
#    Y_High_Bid  Y_Low_Ask
# 0    1.829628   1.829386
# 1    1.830104   1.829916
# 2    1.830604   1.830516
# 3    1.830704   1.831046
# 4    1.830674   1.830886
# 5    1.830568   1.830046

# %% [markdown]
# _________________________![image.png](attachment:37fbba51-5971-4d8d-9ed0-07d57ca94359.png)

# %%
data_ay.tail(10)
# Out:
#         Y_High_Bid  Y_Low_Ask
# 354684    1.824508   1.824852
# 354685    1.824508   1.824952
# 354686    1.824478   1.824852
# 354687    1.824448   1.824852
# 354688    1.824478   1.824952
# 354689    1.824348   1.824752
# 354690    1.824148   1.824552
# 354691    1.824090   1.824252
# 354692    1.823748   1.823852
# 354693    1.823463   1.823852

# %%
# Out:
#         Y_High_Bid  Y_Low_Ask
# 354684    1.824508   1.824852
# 354685    1.824508   1.824952
# 354686    1.824478   1.824852
# 354687    1.824448   1.824852
# 354688    1.824478   1.824952
# 354689    1.824348   1.824752
# 354690    1.824148   1.824552
# 354691    1.824090   1.824252
# 354692    1.823748   1.823852
# 354693    1.823463   1.823852

# %% [markdown]
# ______________________![image.png](attachment:c2336e2d-3c9f-46d7-8154-d7169e0f2b52.png)

# %%
data_ay = data_ay.shift(-1)

# %% [markdown]
# ____________________![image.png](attachment:9f5def32-1021-4d98-9c49-426d4e61d5e9.png)

# %%
data_ay.head(6)
# Out:
#    Y_High_Bid  Y_Low_Ask
# 0    1.830104   1.829916
# 1    1.830604   1.830516
# 2    1.830704   1.831046
# 3    1.830674   1.830886
# 4    1.830568   1.830046
# 5    1.830244   1.830076

# %%
# Out:
#    Y_High_Bid  Y_Low_Ask
# 0    1.830104   1.829916
# 1    1.830604   1.830516
# 2    1.830704   1.831046
# 3    1.830674   1.830886
# 4    1.830568   1.830046
# 5    1.830244   1.830076

# %% [markdown]
# ____________________![image.png](attachment:fc142207-1818-4a9d-aa15-b0b8d03b3018.png)

# %%
data_ay.tail(10)
# Out:
#         Y_High_Bid  Y_Low_Ask
# 354684    1.824508   1.824952
# 354685    1.824478   1.824852
# 354686    1.824448   1.824852
# 354687    1.824478   1.824952
# 354688    1.824348   1.824752
# 354689    1.824148   1.824552
# 354690    1.824090   1.824252
# 354691    1.823748   1.823852
# 354692    1.823463   1.823852
# 354693         NaN        NaN

# %%
# Out:
#         Y_High_Bid  Y_Low_Ask
# 354684    1.824508   1.824952
# 354685    1.824478   1.824852
# 354686    1.824448   1.824852
# 354687    1.824478   1.824952
# 354688    1.824348   1.824752
# 354689    1.824148   1.824552
# 354690    1.824090   1.824252
# 354691    1.823748   1.823852
# 354692    1.823463   1.823852
# 354693         NaN        NaN

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cell.

# %%
# create new colomns: MIN_Lowest(Low_Ask) and MAX_Highest(High_Bid) prices of DURING NEXT 5 minutes

# Forward-looking window
indexer = pd.api.indexers.FixedForwardWindowIndexer(window_size=5)

data_ay['Y_High_Bid_5'] = data_ay['Y_High_Bid'].rolling(window=indexer).max()
data_ay['Y_Low_Ask_5']  = data_ay['Y_Low_Ask'].rolling(window=indexer).min()

# %% [markdown]
# ___________________![image.png](attachment:31f0c5af-51c3-4aff-8652-b2fd4d2c000f.png)

# %%
data_ay.head(6)
# Out:
#    Y_High_Bid  Y_Low_Ask  Y_High_Bid_5  Y_Low_Ask_5
# 0    1.830104   1.829916      1.830704     1.829916
# 1    1.830604   1.830516      1.830704     1.830046
# 2    1.830704   1.831046      1.830704     1.829896
# 3    1.830674   1.830886      1.830968     1.829896
# 4    1.830568   1.830046      1.831624     1.829896
# 5    1.830244   1.830076      1.831624     1.829896

# %%
# Out:
#    Y_High_Bid  Y_Low_Ask  Y_High_Bid_5  Y_Low_Ask_5
# 0    1.830104   1.829916      1.830704     1.829916
# 1    1.830604   1.830516      1.830704     1.830046
# 2    1.830704   1.831046      1.830704     1.829896
# 3    1.830674   1.830886      1.830968     1.829896
# 4    1.830568   1.830046      1.831624     1.829896
# 5    1.830244   1.830076      1.831624     1.829896

# %% [markdown]
# _______________________![image.png](attachment:d38764a0-5d98-42e7-93e7-84226f43af79.png)

# %%
data_ay.tail(10)
# Out:
#         Y_High_Bid  Y_Low_Ask  Y_High_Bid_5  Y_Low_Ask_5
# 354684    1.824508   1.824952      1.824508     1.824752
# 354685    1.824478   1.824852      1.824478     1.824552
# 354686    1.824448   1.824852      1.824478     1.824252
# 354687    1.824478   1.824952      1.824478     1.823852
# 354688    1.824348   1.824752      1.824348     1.823852
# 354689    1.824148   1.824552           NaN          NaN
# 354690    1.824090   1.824252           NaN          NaN
# 354691    1.823748   1.823852           NaN          NaN
# 354692    1.823463   1.823852           NaN          NaN
# 354693         NaN        NaN           NaN          NaN

# %%
# Out:
#         Y_High_Bid  Y_Low_Ask  Y_High_Bid_5  Y_Low_Ask_5
# 354684    1.824508   1.824952      1.824508     1.824752
# 354685    1.824478   1.824852      1.824478     1.824552
# 354686    1.824448   1.824852      1.824478     1.824252
# 354687    1.824478   1.824952      1.824478     1.823852
# 354688    1.824348   1.824752      1.824348     1.823852
# 354689    1.824148   1.824552           NaN          NaN
# 354690    1.824090   1.824252           NaN          NaN
# 354691    1.823748   1.823852           NaN          NaN
# 354692    1.823463   1.823852           NaN          NaN
# 354693         NaN        NaN           NaN          NaN

# %% [markdown]
# __________________________![image.png](attachment:9ee5b5ae-36c2-4667-80f4-0b44ab817433.png)

# %%
data_ay = data_ay.drop(['Y_High_Bid', 'Y_Low_Ask'], axis=1)

# %% [markdown]
# ____________________![image.png](attachment:69998979-62d6-4d99-a0b9-4decd15e990f.png)

# %%
data_ay.tail(6)
# Out:
#         Y_High_Bid_5  Y_Low_Ask_5
# 354688      1.824348     1.823852
# 354689           NaN          NaN
# 354690           NaN          NaN
# 354691           NaN          NaN
# 354692           NaN          NaN
# 354693           NaN          NaN

# %%
# Out:
#         Y_High_Bid_5  Y_Low_Ask_5
# 354688      1.824348     1.823852
# 354689           NaN          NaN
# 354690           NaN          NaN
# 354691           NaN          NaN
# 354692           NaN          NaN
# 354693           NaN          NaN

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next 2 cells.

# %%
# delete the 5 last rows in data_ay (because we don't have answers for the last 5 minutes)

for i in range(5):
        data_ay.drop(data_ay.shape[0]-1, axis=0, inplace=True)

# %%
# delete the last 5 rows in data_ax (because we don't have answers for the last 5 minutes)

for i in range(5):
    data_ax.drop(data_ax.shape[0]-1, axis=0, inplace=True)

# %% [markdown]
# _______________________![image.png](attachment:85d69f40-a645-471c-98e4-efb920bfc01b.png)

# %%
data_ay.shape
# Out:
# (354689, 2)

# %%
# Out:
# (354689, 2)

# %% [markdown]
# ____________________![image.png](attachment:505d3dc3-0958-4691-96e1-7086c3890499.png)

# %%
data_ax.shape
# Out:
# (354689, 18)

# %%
# Out:
# (354689, 18)

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cell.

# %%
# Create inputs Numpy

data_a = np.array(data_ax) 

with np.printoptions(precision=4):
    print("data_a:")
    print(data_a[:2,:])  
    print('\n')
    print(data_a[-2:,:]) 

print("numpy size: = ", data_a.shape)
print("type: ", data_a.dtype)
# Out:
# data_a:
# [[1.8286e+00 1.8296e+00 1.8285e+00 1.8295e+00 9.7176e-03 1.8297e+00
#   1.8309e+00 1.8294e+00 1.8302e+00 9.0501e-03 6.2905e-01 7.0896e-04
#   7.5183e-01 6.9138e-01 8.0142e-01 8.3684e-01 1.0000e+00 1.0000e+00]
#  [1.8295e+00 1.8301e+00 1.8294e+00 1.8300e+00 7.1508e-03 1.8299e+00
#   1.8307e+00 1.8299e+00 1.8306e+00 9.9463e-03 6.3137e-01 2.9690e-03
#   8.9823e-01 8.6517e-01 8.7792e-01 8.5195e-01 0.0000e+00 0.0000e+00]]
#
#
# [[1.8243e+00 1.8244e+00 1.8243e+00 1.8243e+00 2.5520e-03 1.8250e+00
#   1.8251e+00 1.8249e+00 1.8250e+00 2.3750e-03 6.2938e-01 1.8801e-04
#   8.5053e-01 8.5762e-01 8.7178e-01 8.5762e-01 0.0000e+00 0.0000e+00]
#  [1.8244e+00 1.8245e+00 1.8243e+00 1.8243e+00 1.7923e-03 1.8250e+00
#   1.8251e+00 1.8250e+00 1.8250e+00 1.3867e-03 6.2923e-01 4.3086e-04
#   8.6470e-01 8.6470e-01 8.5762e-01 8.5762e-01 0.0000e+00 0.0000e+00]]
# numpy size: =  (354689, 18)
# type:  float32

# %%
# Chech the result:
# Your result from running the cell above must match the result in this cell.
# Out:
# data_a:
# [[1.8286e+00 1.8296e+00 1.8285e+00 1.8295e+00 9.7176e-03 1.8297e+00
#   1.8309e+00 1.8294e+00 1.8302e+00 9.0501e-03 6.2905e-01 7.0896e-04
#   7.5183e-01 6.9138e-01 8.0142e-01 8.3684e-01 1.0000e+00 1.0000e+00]
#  [1.8295e+00 1.8301e+00 1.8294e+00 1.8300e+00 7.1508e-03 1.8299e+00
#   1.8307e+00 1.8299e+00 1.8306e+00 9.9463e-03 6.3137e-01 2.9690e-03
#   8.9823e-01 8.6517e-01 8.7792e-01 8.5195e-01 0.0000e+00 0.0000e+00]]
#
#
# [[1.8243e+00 1.8244e+00 1.8243e+00 1.8243e+00 2.5520e-03 1.8250e+00
#   1.8251e+00 1.8249e+00 1.8250e+00 2.3750e-03 6.2938e-01 1.8801e-04
#   8.5053e-01 8.5762e-01 8.7178e-01 8.5762e-01 0.0000e+00 0.0000e+00]
#  [1.8244e+00 1.8245e+00 1.8243e+00 1.8243e+00 1.7923e-03 1.8250e+00
#   1.8251e+00 1.8250e+00 1.8250e+00 1.3867e-03 6.2923e-01 4.3086e-04
#   8.6470e-01 8.6470e-01 8.5762e-01 8.5762e-01 0.0000e+00 0.0000e+00]]
# numpy size: =  (354689, 18)
# type:  float32

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cell.

# %%
# Create outputs Numpy

data_y = np.array(data_ay) 

print("data_a:")
print(data_y[:3,:])  
print('\n')
print(data_y[-3:,:]) 

print("numpy size: = ", data_y.shape)
print("type: ", data_y.dtype)
# Out:
# data_a:
# [[1.83070397 1.829916  ]
#  [1.83070397 1.83004606]
#  [1.83070397 1.82989597]]
#
#
# [[1.82447803 1.82425201]
#  [1.82447803 1.82385194]
#  [1.82434797 1.82385194]]
# numpy size: =  (354689, 2)
# type:  float64

# %%
# Chech the result:
# Your result from running the cell above must match the result in this cell.
# Out:
# data_a:
# [[1.83070397 1.829916  ]
#  [1.83070397 1.83004606]
#  [1.83070397 1.82989597]]
#
#
# [[1.82447803 1.82425201]
#  [1.82447803 1.82385194]
#  [1.82434797 1.82385194]]
# numpy size: =  (354689, 2)
# type:  float64

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> Create the 3D inputs tensor, and 2D outputs matrix </h3> </html>

# %%
# We will analyse only part of the dataset since training the neural network with 
# an entire dataset would require massive computer power.

# n_small = 30,000 rows (minutes), which equals around 1 month.

# We need a three-dimensional data tensor: [(n_small-N ), N, 18] and
# two-dimensional array of answers [(n_small-N ), 2] with the High and Low prices DURING the next 5 minutes

# where N=50 is the number of minutes for analysis at each step; those are looking backwards 

# Therefore, we need:
# three-dimensional data tensor of sliced graphs [(n_small - N - 5), N, 18] and
# two-dimensional matrix of answers Y[(n_small - N - 5), 2] with the High and Low prices shifted sequentially to 5 rows up.

# %% [markdown]
# ________________________![image.png](attachment:a40acf43-52bc-4f48-b4aa-6bb9cf888cec.png)

# %%
from tqdm import tqdm

# %% [markdown]
# ___________________________![image.png](attachment:7e498656-b74b-4ab4-a897-8b79b19ecea7.png)

# %%
n_small = 30000
N=50
L=n_small-N
t=data_a.shape[1]
print('Size of a three-dimensional inputs tensor: ',L,N,t)
# Out:
# Size of a three-dimensional inputs tensor:  29950 50 18

# %%
# Out:
# Size of a three-dimensional inputs tensor:  29950 50 18

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next 3 cells.

# %%
# create imputs zeros 3D tensors with 'float32'

data_b = np.zeros( (L, N, t), dtype= 'float32' )

# %%
# create a two-dimensional zeros vector of answers - normalised the High_Bid and Low_Ask prices DURING next 5 minutes

Y = np.zeros((L, 2), dtype= 'float32') # We will predict two prices - normalised High_Bid and normalised Low_Ask

# %%
# fill the imputs 3D tansor (data_b) 
# and the array of answers Y 

#print('L = n - N = ', n-N, L)
print('L = n_small - N - 5 = ', n_small-N-5, L)
#for k in tqdm(range(L-1)):
for k in tqdm(range(L)):
    data_b[k, :, :] = data_a[k:k+N, :]   
                                          
    Y[k,0] = data_y[k+N-1,0]   # normalised Y_High_Bid - max 5 minutes future price
    Y[k,1] = data_y[k+N-1,1]   # normalised Y_Low_Ask -  min 5 minutes future price

print(k) # index value (for control)
    
print('data_b:', '\n', data_b)
print("Numpy size:        ", data_b.shape, '\n')

print( Y[:5,:])
print( Y[-10:,:])
print(      "Numpy size:         ", Y.shape)
# Out:
# L = n_small - N - 5 =  29945 29950
# 100%|██████████| 29950/29950 [00:00<00:00, 85323.45it/s]
# 29949
# data_b:
#  [[[1.828604   1.829628   1.828544   ... 0.8368359  1.         1.        ]
#  [1.800318 1.798795]]
# Numpy size:          (29950, 2)

# %%
# Chech the result:
# Your result from running the cell above must match the result in this cell.
# Out:
# L = n_small - N - 5 =  29945 29950
# 100%|██████████| 29950/29950 [00:00<00:00, 347057.11it/s]
# 29949
# data_b:
#  [[[1.828604   1.829628   1.828544   ... 0.8368359  1.         1.        ]
#   [1.829504   1.830104   1.829398   ... 0.851948   0.         0.        ]
#   [1.830098   1.830604   1.829998   ... 0.85572606 0.         0.        ]
#   ...
#   [1.828188   1.828198   1.828058   ... 0.9048406  0.         0.        ]
#   [1.828178   1.828178   1.827978   ... 0.90247935 0.         0.        ]
#   [1.827998   1.828058   1.827968   ... 0.90247935 0.         0.        ]]
#
#  [[1.829504   1.830104   1.829398   ... 0.851948   0.         0.        ]
#   [1.830098   1.830604   1.829998   ... 0.85572606 0.         0.        ]
#   [1.830534   1.830704   1.830504   ... 0.91239667 0.         0.        ]
#   ...
#   [1.828178   1.828178   1.827978   ... 0.90247935 0.         0.        ]
#   [1.827998   1.828058   1.827968   ... 0.90247935 0.         0.        ]
#   [1.828048   1.828158   1.827898   ... 0.89681226 0.         0.        ]]
#
#  [[1.830098   1.830604   1.829998   ... 0.85572606 0.         0.        ]
#   [1.830534   1.830704   1.830504   ... 0.91239667 0.         0.        ]
#   [1.830674   1.830674   1.830448   ... 0.86375445 0.         0.        ]
#   ...
#   [1.827998   1.828058   1.827968   ... 0.90247935 0.         0.        ]
#   [1.828048   1.828158   1.827898   ... 0.89681226 0.         0.        ]
#   [1.828158   1.828178   1.828108   ... 0.89350647 0.         0.        ]]
#
#  ...
#
#  [[1.801748   1.801848   1.801528   ... 0.9142857  0.         0.        ]
#   [1.801548   1.801728   1.801538   ... 0.91829985 0.         0.        ]
#   [1.801638   1.801748   1.801588   ... 0.92136955 0.         0.        ]
#   ...
#   [1.800525   1.800525   1.799828   ... 0.92302245 0.         0.        ]
#   [1.799918   1.800008   1.799758   ... 0.927745   0.         0.        ]
#   [1.799878   1.799878   1.799568   ... 0.9237308  0.         0.        ]]
#
#  [[1.801548   1.801728   1.801538   ... 0.91829985 0.         0.        ]
#   [1.801638   1.801748   1.801588   ... 0.92136955 0.         0.        ]
#   [1.801668   1.801728   1.801502   ... 0.92136955 0.         0.        ]
#   ...
#   [1.799918   1.800008   1.799758   ... 0.927745   0.         0.        ]
#   [1.799878   1.799878   1.799568   ... 0.9237308  0.         0.        ]
#   [1.799918   1.799918   1.799398   ... 0.9260921  0.         0.        ]]
#
#  [[1.801638   1.801748   1.801588   ... 0.92136955 0.         0.        ]
#   [1.801668   1.801728   1.801502   ... 0.92136955 0.         0.        ]
#   [1.801618   1.801748   1.801428   ... 0.9142857  0.         0.        ]
#   ...
#   [1.799878   1.799878   1.799568   ... 0.9237308  0.         0.        ]
#   [1.799918   1.799918   1.799398   ... 0.9260921  0.         0.        ]
#   [1.799588   1.799838   1.799218   ... 0.91829985 0.         0.        ]]]
# Numpy size:         (29950, 50, 18)
#
# [[1.828358 1.828342]
#  [1.828388 1.828546]
#  [1.828388 1.828602]
#  [1.828388 1.828602]
#  [1.828388 1.828602]]
# [[1.801078 1.800142]
#  [1.801078 1.800095]
#  [1.800908 1.799901]
#  [1.800908 1.799742]
#  [1.800525 1.799565]
#  [1.800008 1.798795]
#  [1.799918 1.798795]
#  [1.800258 1.798795]
#  [1.800318 1.798795]
#  [1.800318 1.798795]]
# Numpy size:          (29950, 2)

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cell.

# %%
# Control of the correctness of filling the array Y 
# (should show MAX of the normalised prices High_Bid and Low_Ask - during 5 next minutes(step) ahead)


import random

pp = random.randint(50, L) # (any number before 29950) - just to look at the middle of data_b
print('random int = ', pp)

print('data_b:', '\t\t','Y:')
print('Y_High_Bid ','\t\t','Y_High_Bid')

for i in range(15):
    print(data_b[pp+i,N-1,1], '\t\t', Y[pp+i,0])
# Out:
# random int =  7380
# data_b: 		 Y:
# Y_High_Bid  		 Y_High_Bid
# 1.795058 		 1.795265
# 1.795038 		 1.795305
# 1.794798 		 1.795305
# 1.794928 		 1.795305
# 1.795265 		 1.795305
# 1.795218 		 1.795305
# 1.795305 		 1.795208
# 1.795208 		 1.795008
# 1.795008 		 1.794515
# 1.794515 		 1.793778
# 1.793778 		 1.793708
# 1.793708 		 1.793498
# 1.792998 		 1.793498
# 1.793248 		 1.793498
# 1.793268 		 1.793498

# %%
# Out:
# random int =  23368
# data_b: 		 Y:
# Y_High_Bid  		 Y_High_Bid
# 1.847478 		 1.847648
# 1.847568 		 1.847648
# 1.847648 		 1.847568
# 1.847568 		 1.847558
# 1.847558 		 1.847508
# 1.847468 		 1.847508
# 1.847508 		 1.847508
# 1.847508 		 1.847558
# 1.847418 		 1.847808
# 1.847488 		 1.848198
# 1.847494 		 1.848248
# 1.847358 		 1.848248
# 1.847558 		 1.848248
# 1.847808 		 1.848588
# 1.848198 		 1.848588

# %%
# Each rows of Y above must have maximum of prices of 5 minute ahead
# you can run several times the cell above

# %% [markdown]
# _________________________![image.png](attachment:9ab05117-ce0f-49fe-ae30-4179c03e73c9.png)

# %%
data = []
data_ax = []
data_ay = []
data_a = []
data_y = []

# %% [markdown]
# <html> <h2 style="font-style:italic; olor:blue;"> Train Test Split </h2> </html>
#
# - 90% for training and validation
# - 10% for testing

# %% [markdown]
# _________________________![image.png](attachment:6a4fcda7-5078-4e89-a50c-2fb67dd43772.png)

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# <html> <h3 style="font-style:bold; color:red;"> !!! Use parameters: shuffle = False, stratify = None
#
# Otherwise, the whole time series will be mixed up!
# </h3> </html>

# %% [markdown]
# ________________![image.png](attachment:22312254-f6d6-4496-9f85-cbcf4a99e7e2.png)

# %%
X_train, X_test, y_train, y_test = train_test_split(data_b, Y, test_size=0.1, shuffle=False, stratify=None, random_state=101)

# %% [markdown]
# _____________![image.png](attachment:b79a1273-ab1d-4525-a6db-27b4639b35ca.png)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (26955, 50, 18)
# (26955, 2)
# (2995, 50, 18)
# (2995, 2)

# %%
# Out:
# (26955, 50, 18)
# (26955, 2)
# (2995, 50, 18)
# (2995, 2)

# %% [markdown]
# <html> <h2 style="color:blue;"> Training </h2> </html>

# %% [markdown]
# <html> <h3 style="color:blue;"> LSTM </h3> </html>

# %% [markdown]
# ___________________________![image.png](attachment:4d8d6d7f-f33d-4c92-8483-9bbd9a2466c8.png)

# %%
model = keras.Sequential([keras.layers.LSTM(100, activation='relu', input_shape=(50,18)), keras.layers.Dense(2)])
# Out:
# C:\Users\srava\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Out:
# C:\Users\vital\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# _________________________![image.png](attachment:6aa5d24d-9b71-4ce1-ba05-8a4491077cda.png)

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 100)            │        47,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           202 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 47,802 (186.73 KB)
#  Trainable params: 47,802 (186.73 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100)            │        47,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │           202 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 47,802 (186.73 KB)
#  Trainable params: 47,802 (186.73 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> Callbacks </h3> </html>

# %% [markdown]
# __________________________![image.png](attachment:8be9a46e-ce3b-4b4a-9c89-25d7ba033d03.png)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mae"])

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cell.

# %%
# Early Stopping parameters

es = EarlyStopping(monitor='val_loss', mode='min', patience=5, verbose=1)
mc = ModelCheckpoint('best_model_LSTM_GOLD.keras', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %% [markdown]
# <html> <h4 style="font-style:bold; color:red;"> If you are using your own laptop without a GPU (Graphics processing unit),
#
# please change the following parameter in the next cell  </h4> </html>
# <html> <h3 style="font-style:bold; color:blue;">
# epochs=10
# </h3> </html>

# %% [markdown]
# __________________________![image.png](attachment:84fb1bd1-406e-4fd2-a086-5998ad9e1dcd.png)

# %%
history = model.fit(X_train, y_train, batch_size=20, epochs=10, validation_split=0.1, shuffle=True, verbose=1, callbacks=[es,mc])
# Out:
# Epoch 1/10
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0233 - mae: 0.0382
# Epoch 1: val_loss improved from None to 0.00002, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 47s 37ms/step - loss: 0.0036 - mae: 0.0097 - val_loss: 1.6851e-05 - val_mae: 0.0026
# Epoch 2/10
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.5872e-05 - mae: 0.0030
# Epoch 2: val_loss did not improve from 0.00002
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - loss: 1.5276e-05 - mae: 0.0029 - val_loss: 1.7354e-05 - val_mae: 0.0028
# Epoch 3/10
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.6242e-05 - mae: 0.0031
# Epoch 3: val_loss improved from 0.00002 to 0.00001, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 44s 36ms/step - loss: 1.6601e-05 - mae: 0.0031 - val_loss: 1.4491e-05 - val_mae: 0.0028
# Epoch 4/10
# 1212/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.5060e-05 - mae: 0.0030
# Epoch 4: val_loss improved from 0.00001 to 0.00001, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 44s 36ms/step - loss: 1.5160e-05 - mae: 0.0030 - val_loss: 9.4481e-06 - val_mae: 0.0022
# Epoch 5/10
# 1212/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.0878e-05 - mae: 0.0036
# Epoch 5: val_loss improved from 0.00001 to 0.00001, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 43s 36ms/step - loss: 2.1380e-05 - mae: 0.0036 - val_loss: 9.0144e-06 - val_mae: 0.0023
# Epoch 6/10
# 1212/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.2873e-05 - mae: 0.0037
# Epoch 6: val_loss improved from 0.00001 to 0.00000, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 44s 36ms/step - loss: 2.6666e-05 - mae: 0.0040 - val_loss: 4.1725e-06 - val_mae: 0.0016
# Epoch 7/10
# 1212/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.1180e-05 - mae: 0.0036
# Epoch 7: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - loss: 2.5013e-05 - mae: 0.0040 - val_loss: 6.4690e-05 - val_mae: 0.0078
# Epoch 8/10
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.6744e-05 - mae: 0.0040
# Epoch 8: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 42s 35ms/step - loss: 2.3595e-05 - mae: 0.0038 - val_loss: 5.7876e-06 - val_mae: 0.0021
# Epoch 9/10
# 1212/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.0468e-05 - mae: 0.0036
# Epoch 9: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 43s 36ms/step - loss: 2.1099e-05 - mae: 0.0037 - val_loss: 1.6962e-05 - val_mae: 0.0037
# Epoch 10/10
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.8862e-05 - mae: 0.0034
# Epoch 10: val_loss improved from 0.00000 to 0.00000, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 43s 36ms/step - loss: 1.8591e-05 - mae: 0.0034 - val_loss: 3.3798e-06 - val_mae: 0.0016

# %%
# Out:
# Epoch 1/20
# 1211/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0529 - mae: 0.0523
# Epoch 1: val_loss improved from inf to 0.00002, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - loss: 0.0527 - mae: 0.0522 - val_loss: 2.0870e-05 - val_mae: 0.0033
# Epoch 2/20
# 1210/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9688e-05 - mae: 0.0035
# Epoch 2: val_loss improved from 0.00002 to 0.00002, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 1.9688e-05 - mae: 0.0035 - val_loss: 1.8964e-05 - val_mae: 0.0032
# Epoch 3/20
# 1212/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0251e-05 - mae: 0.0035
# Epoch 3: val_loss did not improve from 0.00002
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 2.0252e-05 - mae: 0.0035 - val_loss: 1.9401e-05 - val_mae: 0.0038
# Epoch 4/20
# 1210/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3436e-05 - mae: 0.0038
# Epoch 4: val_loss improved from 0.00002 to 0.00002, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 2.3450e-05 - mae: 0.0038 - val_loss: 1.8706e-05 - val_mae: 0.0037
# Epoch 5/20
# 1211/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0718e-05 - mae: 0.0044
# Epoch 5: val_loss did not improve from 0.00002
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 3.0722e-05 - mae: 0.0044 - val_loss: 3.8604e-05 - val_mae: 0.0055
# Epoch 6/20
# 1210/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9905e-05 - mae: 0.0044
# Epoch 6: val_loss improved from 0.00002 to 0.00000, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 2.9904e-05 - mae: 0.0044 - val_loss: 3.9406e-06 - val_mae: 0.0015
# Epoch 7/20
# 1212/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2089e-05 - mae: 0.0044
# Epoch 7: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 3.2080e-05 - mae: 0.0044 - val_loss: 7.1235e-06 - val_mae: 0.0023
# Epoch 8/20
# 1211/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4646e-05 - mae: 0.0039
# Epoch 8: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 14s 12ms/step - loss: 2.4644e-05 - mae: 0.0039 - val_loss: 4.7874e-06 - val_mae: 0.0018
# Epoch 9/20
# 1210/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7988e-05 - mae: 0.0033
# Epoch 9: val_loss improved from 0.00000 to 0.00000, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 1.7992e-05 - mae: 0.0033 - val_loss: 3.0009e-06 - val_mae: 0.0013
# Epoch 10/20
# 1211/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6848e-05 - mae: 0.0033
# Epoch 10: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 1.6850e-05 - mae: 0.0033 - val_loss: 4.5427e-06 - val_mae: 0.0019
# Epoch 11/20
# 1209/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5444e-05 - mae: 0.0031
# Epoch 11: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 1.5445e-05 - mae: 0.0031 - val_loss: 1.4737e-05 - val_mae: 0.0037
# Epoch 12/20
# 1211/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8235e-05 - mae: 0.0034
# Epoch 12: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 1.8231e-05 - mae: 0.0034 - val_loss: 4.9655e-06 - val_mae: 0.0020
# Epoch 13/20
# 1211/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7521e-05 - mae: 0.0030
# Epoch 13: val_loss improved from 0.00000 to 0.00000, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 4.7766e-05 - mae: 0.0030 - val_loss: 1.9344e-06 - val_mae: 0.0010
# Epoch 14/20
# 1212/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8937e-06 - mae: 0.0011
# Epoch 14: val_loss improved from 0.00000 to 0.00000, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 1.8937e-06 - mae: 0.0011 - val_loss: 1.5162e-06 - val_mae: 9.1248e-04
# Epoch 15/20
# 1212/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0338e-06 - mae: 0.0013
# Epoch 15: val_loss improved from 0.00000 to 0.00000, saving model to best_model_LSTM_GOLD.keras
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 3.0354e-06 - mae: 0.0013 - val_loss: 1.3340e-06 - val_mae: 8.2486e-04
# Epoch 16/20
# 1209/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.9042e-06 - mae: 0.0024
# Epoch 16: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 8.9064e-06 - mae: 0.0024 - val_loss: 2.9851e-05 - val_mae: 0.0054
# Epoch 17/20
# 1212/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1023e-05 - mae: 0.0027
# Epoch 17: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 1.1022e-05 - mae: 0.0027 - val_loss: 3.5438e-06 - val_mae: 0.0017
# Epoch 18/20
# 1211/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0073e-05 - mae: 0.0026
# Epoch 18: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 1.0072e-05 - mae: 0.0026 - val_loss: 1.5843e-05 - val_mae: 0.0038
# Epoch 19/20
# 1210/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.9131e-06 - mae: 0.0025
# Epoch 19: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 9.9127e-06 - mae: 0.0025 - val_loss: 2.1386e-05 - val_mae: 0.0045
# Epoch 20/20
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.9535e-06 - mae: 0.0022
# Epoch 20: val_loss did not improve from 0.00000
# 1213/1213 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 8.9534e-06 - mae: 0.0022 - val_loss: 2.3260e-05 - val_mae: 0.0047
# Epoch 20: early stopping

# %% [markdown]
# _______________________________![image.png](attachment:5374a74e-a765-4c25-bc7d-865465d81e0f.png)

# %%
LSTM_saved_best_model = keras.models.load_model('best_model_LSTM_GOLD.keras')

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> Test </h3> </html>

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next 4 cells.

# %%
# Evaluate the quality of network training on test data, which the network has NOT seen.

scores = LSTM_saved_best_model.evaluate(X_test, y_test, verbose=1)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 3.2059e-06 - mae: 0.0016

# %%
scores
# Out:
# [3.2059208479040535e-06, 0.0016005357028916478]

# %%
print("Mean squared error (mse): %.9f " % (scores[0]))
# Out:
# Mean squared error (mse): 0.000003206

# %%
print("Mean absolute error (mae): %.9f " % (scores[1]))
# Out:
# Mean absolute error (mae): 0.001600536

# %% [markdown]
# <html> <h2 style="font-style:italic; color:blue;"> Visualisation </h2> </html>

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> MSE training graphs </h3> </html>

# %% [markdown]
# ___________________________![image.png](attachment:a0505e18-9a4a-438b-9395-e5c301a7eb5e.png)

# %%
plt.plot(history.history['loss'])
plt.xlabel('Mean Squared Error', size=14)
plt.show()

# %%
# Out:
# Text(0.5, 0, 'Mean Squared Error')

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next 2 cells.

# %%
# More detailed MSE graph

history_dict = history.history

mse_values = history_dict['loss']
val_mse_values = history_dict['val_loss']

epochs = range(1, len(mse_values) + 1)
plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, mse_values, 'b', label='Training Mean Squared Error (MSE)')
plt.plot(epochs, val_mse_values, marker='o', markeredgecolor='red', markerfacecolor='yellow', label='Validation Mean Squared Error (MSE)')
plt.xlabel('Epochs', size=18)
plt.ylabel('Mean Squared Error (MSE)', size=18)
plt.legend()
plt.show()

# %%
# deleted the 1st epoch
# to examine in detail the results of the remaining epochs

history_dict = history.history

mse_values = history_dict['loss'][1:]
val_mse_values = history_dict['val_loss'][1:]

epochs = range(1, len(mse_values) + 1)
plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, mse_values, 'b', label='Training Mean Squared Error (MSE)')
plt.plot(epochs, val_mse_values, marker='o', markeredgecolor='red', markerfacecolor='yellow', label='Validation Mean Squared Error (MSE)')
plt.xlabel('Epochs', size=18)
plt.ylabel('Mean Squared Error (MSE)', size=18)
plt.legend()
plt.show()

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> MAE training graphs </h3> </html>

# %% [markdown]
# __________________![image.png](attachment:18ec4952-06a9-4505-b2c2-b9cca555500c.png)

# %%
plt.plot(history.history['mae'])
plt.xlabel('Mean Absolute Error', size=14)
plt.show()

# %% [markdown]
# ____![image.png](attachment:8233e730-22b4-4ce7-8de2-77416c7655a8.png)

# %%
history_dict = history.history
mae_values = history_dict['val_mae']
val_mae_values = history_dict['val_mae']
epochs = range(1,len(mae_values) + 1)
plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, mae_values, 'b', label='Training Mean Absolute Error(MAE)')
plt.plot(epochs, val_mae_values, marker='o', markeredgecolor='green', markerfacecolor='yellow', label='Validation Mean Absolute Error(MAE)')
plt.xlabel('Epochs', size=18)
plt.ylabel('Mean Absolute Error(MAE)', size=18)
plt.legend()
plt.show()
# Out:
# C:\Users\srava\AppData\Local\Temp\ipykernel_29440\1958381716.py:5: UserWarning: Ignoring specified arguments in this call because figure with num: 1 already exists
#   plt.figure(num=1, figsize=(15,7))

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> Prediction 5 minute ahead </h3> </html>

# %% [markdown]
# ![image.png](attachment:973f4326-7a0b-462a-b278-ffd23c74d7c9.png)

# %%
pred = LSTM_saved_best_model(X_test)
print(pred)
# Out:
# tf.Tensor(
# [[1.7868057 1.7852565]
#  [1.7865992 1.7852503]
#  [1.7866436 1.7848712]
#  ...
#  [1.8018438 1.8015795]
#  [1.8015947 1.8015953]
#  [1.8020555 1.800639 ]], shape=(2995, 2), dtype=float32)

# %%
# Out:
# tf.Tensor(
# [[1.7847013 1.7831059]
#  [1.7841758 1.7829924]
#  [1.7838504 1.7827185]
#  ...
#  [1.800886  1.8009316]
#  [1.8011881 1.8008903]
#  [1.8007932 1.800265 ]], shape=(2995, 2), dtype=float32)

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> Price chart </h3> </html>

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cell.

# %%
N1=2500  # The first minute for the chart  
LL = 500  # Duration (in minutes) for the chart
N2=N1+LL  # the last minute for the chart

plt.ion()
fig = plt.figure(figsize=(15,7))  

ax1 = fig.add_subplot(111)
line1, = ax1.plot(y_test[N1:N2,0], label='High_Bid')
line2, = ax1.plot(pred[N1:N2,0], label='Predicted High_Bid')
line3, = ax1.plot(y_test[N1:N2,1], label='Low_Ask')
line4, = ax1.plot(pred[N1:N2,1], label='Predicted Low_Ask')

plt.title('Real & Predicted Prices', size=22)
plt.ylabel('GOLD Prices (thousands $)', size=18)
plt.xlabel('$Minutes$', size=18)
plt.legend(loc='upper right') 

plt.show()

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> Error Chart </h3> </html>

# %% [markdown]
# __________________![image.png](attachment:b507c905-e3a6-47e9-b65e-d4b512c82410.png)

# %%
max_price = 2070.778
min_price = 1614.71
aerage_price = (max_price + min_price)/2

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cell.

# %%
N1=0  # The first minute for the chart  
LL = 1500  # leigt (in minutes) for the chart
N2=N1+LL  # the last minute for the chart
# N2 should be < len(pred)

plt.ion()
fig = plt.figure(figsize=(15,7))  

ax1 = fig.add_subplot(111)

# in $ (absolute price)
a = (pred[N1:N2,0] - y_test[N1:N2,0]) *1000
b = (pred[N1:N2,1] - y_test[N1:N2,1]) *1000

# in %
#a = (pred[N1:N2,0] - y_test[N1:N2,0]) *1000/ average_price *100
#b = (pred[N1:N2,1] - y_test[N1:N2,1]) *1000/ average_price *100


line1, = ax1.plot(a, label='Predicted High_Bid Error')
line2, = ax1.plot(b, label='Predicted Low_Ask Error')

plt.title('Error GOLD price Chart', size=22)
plt.ylabel('Predicted Error GOLD Prices', size=18)
plt.xlabel('$Minutes$', size=18)
plt.legend(loc='upper right') 

plt.show()

# %% [markdown]
# # Lab Logbook Requirement:

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">
#
# 1) Modify the practical session LSTM model parameter from 100 to be calculated using the formula:
#
#    ZY + 10
#    , where your SID is: XXXXXZY
#
#    (For example, if your SID is 2287167, then LSTM model parameter = 67+10=77)
# 3) Change the epochs to 10.
# 4) Change the patience to 3
# 5) Leave other parameters the same as in the practical session.
# 6) Compile the model.
# 6) Train your LSTM with the same datasets and demonstrate the received test MSE & MAE.
# Compare your test MSE & MAE with the MSE & MAE of the LSTM in the practical session.
# 7) Please only add to your Lab Logbook the print-screens of:
# - your LSTM architecture using model.summary(),
# - training process,
# - the resulting test MSE & MAE and
# - MAE detailed graph.
#
#
#
# </h3> </html>

# %% [markdown]
# <html> <h3 style="color:red;">
# NOTE: DON'T FORGET TO SAVE AND BACK UP YOUR COMPLETED JUPYTER NOTEBOOK AND LAB LOGBOOK, AND UPLOAD THE LAB LOGBOOK REQUIREMENTS AS A SCREENSHOT OF YOUR CODE AND RESULT(S) ON YOUR GITHUB.
# </h3> </html>
